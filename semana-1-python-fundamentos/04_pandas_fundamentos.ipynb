# %%
import pandas as pd

# %%
df = pd.read_csv("../data/ventas_prueba.csv")

# %%
df
# Out:
#        cliente             producto   monto
# 0   Juan Perez  Persiana enrollable  250000
# 1  Maria Lopez     Cortina blackout  180000
# 2  Carlos Ruiz   Persiana veneciana  320000

# %%
df.head()
# Out:
#        cliente             producto   monto
# 0   Juan Perez  Persiana enrollable  250000
# 1  Maria Lopez     Cortina blackout  180000
# 2  Carlos Ruiz   Persiana veneciana  320000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cliente   3 non-null      str
#  1   producto  3 non-null      str
#  2   monto     3 non-null      int64
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes

# %%
df.describe()
# Out:
#           monto
# count       3.0
# mean   250000.0
# std     70000.0
# min    180000.0
# 25%    215000.0
# 50%    250000.0
# 75%    285000.0
# max    320000.0

# %%
df.dtypes
# Out:
# cliente       str
# producto      str
# monto       int64
# dtype: object

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['cliente', 'producto', 'monto'], dtype='str')

# %%
df["monto"]
# Out:
# 0    250000
# 1    180000
# 2    320000
# Name: monto, dtype: int64

# %%
df[["cliente", "monto"]]
# Out:
#        cliente   monto
# 0   Juan Perez  250000
# 1  Maria Lopez  180000
# 2  Carlos Ruiz  320000

# %%
df.iloc[0]
# Out:
# cliente              Juan Perez
# producto    Persiana enrollable
# monto                    250000
# Name: 0, dtype: object

# %%
df.iloc[2]
# Out:
# cliente            Carlos Ruiz
# producto    Persiana veneciana
# monto                   320000
# Name: 2, dtype: object

# %%
df[df["monto"] > 200000]
# Out:
#        cliente             producto   monto
# 0   Juan Perez  Persiana enrollable  250000
# 2  Carlos Ruiz   Persiana veneciana  320000

# %%
  df["monto"] > 200000
# Out:
# 0     True
# 1    False
# 2     True
# Name: monto, dtype: bool

# %%
  df["monto"] < 200000
# Out:
# 0    False
# 1     True
# 2    False
# Name: monto, dtype: bool

# %%
df["cliente"] == "Juan Perez"
# Out:
# 0    True
# 1    True
# 2    True
# Name: cliente, dtype: bool

# %%
df[df["cliente"] == "Juan Perez"]
# Out:
#       cliente             producto   monto
# 0  Juan Perez  Persiana enrollable  250000
# 1  Juan Perez     Cortina blackout  180000
# 2  Juan Perez   Persiana veneciana  320000

# %%
df
# Out:
#       cliente             producto   monto
# 0  Juan Perez  Persiana enrollable  250000
# 1  Juan Perez     Cortina blackout  180000
# 2  Juan Perez   Persiana veneciana  320000

# %%
df_correcto = pd.DataFrame({
    "cliente": ["Juan Perez", "Maria Lopez", "Carlos Ruiz"],
    "producto": ["Persiana enrollable", "Cortina blackout", "Persiana veneciana"],
    "monto": [250000, 180000, 320000]
})

df_correcto.to_csv("../data/ventas_prueba.csv", index=False)

# %%
df = pd.read_csv("../data/ventas_prueba.csv")

# %%
df
# Out:
#        cliente             producto   monto
# 0   Juan Perez  Persiana enrollable  250000
# 1  Maria Lopez     Cortina blackout  180000
# 2  Carlos Ruiz   Persiana veneciana  320000

# %%
df[df["cliente"] == "Juan Perez"]
# Out:
#       cliente             producto   monto
# 0  Juan Perez  Persiana enrollable  250000

# %%
df["monto_con_iva"] = df["monto"] * 1.19

# %%
df
# Out:
#        cliente             producto   monto  monto_con_iva
# 0   Juan Perez  Persiana enrollable  250000       297500.0
# 1  Maria Lopez     Cortina blackout  180000       214200.0
# 2  Carlos Ruiz   Persiana veneciana  320000       380800.0

# %%
# La forma "manual" (fila por fila), como tendrías que hacerlo sin pandas
resultados = []
for monto in df["monto"]:
    resultados.append(monto * 1.19)
print(resultados)
# Out:
# [297500.0, 214200.0, 380800.0]

# %%
df.groupby("producto")["monto"].sum()
# Out:
# producto
# Cortina blackout       180000
# Persiana enrollable    250000
# Persiana veneciana     320000
# Name: monto, dtype: int64

# %%
df.groupby("cliente")["monto"].mean()
# Out:
# cliente
# Carlos Ruiz    320000.0
# Juan Perez     250000.0
# Maria Lopez    180000.0
# Name: monto, dtype: float64

# %%
df_extra = pd.concat([df, pd.DataFrame({
    "cliente": ["Juan Perez"],
    "producto": ["Persiana enrollable"],
    "monto": [250000],
    "monto_con_iva": [297500.0]
})], ignore_index=True)

df_extra.groupby("cliente")["monto"].sum()
# Out:
# cliente
# Carlos Ruiz    320000
# Juan Perez     500000
# Maria Lopez    180000
# Name: monto, dtype: int64
