# %%
 import pandas as pd

# %%
df = pd.DataFrame({ "cliente": ["Juan Perez", "Maria Lopez", "Carlos Ruiz"], "producto": ["Persiana enrollable", "Cortina blackout", "Persiana romana"], "monto": [250000, 180000, 320000], "fecha": ["2026-09-01", "2026-09-02", "2026-09-03"] })

# %%
 df.head()
# Out:
#        cliente             producto   monto       fecha
# 0   Juan Perez  Persiana enrollable  250000  2026-09-01
# 1  Maria Lopez     Cortina blackout  180000  2026-09-02
# 2  Carlos Ruiz      Persiana romana  320000  2026-09-03

# %%
df.dtypes
# Out:
# cliente       str
# producto      str
# monto       int64
# fecha         str
# dtype: object

# %%
df.shape
# Out:
# (3, 4)
