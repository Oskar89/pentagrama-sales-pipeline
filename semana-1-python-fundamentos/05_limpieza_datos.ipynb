# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.DataFrame({
    "cliente": ["Juan Perez", "Maria Lopez", "Carlos Ruiz", "Maria Lopez", None],
    "producto": ["Persiana enrollable", "Cortina blackout", None, "Cortina blackout", "Persiana veneciana"],
    "monto": ["250000", "180000", "320000", "180000", "150000"],
    "fecha": ["2026-09-01", "2026-09-02", "2026-09-03", "2026-09-02", None]
})

# %%
df
# Out:
#        cliente             producto   monto       fecha
# 0   Juan Perez  Persiana enrollable  250000  2026-09-01
# 1  Maria Lopez     Cortina blackout  180000  2026-09-02
# 2  Carlos Ruiz                  NaN  320000  2026-09-03
# 3  Maria Lopez     Cortina blackout  180000  2026-09-02
# 4          NaN   Persiana veneciana  150000         NaN

# %%
df.isnull()
# Out:
#    cliente  producto  monto  fecha
# 0    False     False  False  False
# 1    False     False  False  False
# 2    False      True  False  False
# 3    False     False  False  False
# 4     True     False  False   True

# %%
df.isnull().sum()
# Out:
# cliente     1
# producto    1
# monto       0
# fecha       1
# dtype: int64

# %%
df_sin_nulos = df.dropna()
df_sin_nulos
# Out:
#        cliente             producto   monto       fecha
# 0   Juan Perez  Persiana enrollable  250000  2026-09-01
# 1  Maria Lopez     Cortina blackout  180000  2026-09-02
# 3  Maria Lopez     Cortina blackout  180000  2026-09-02

# %%
df_relleno = df.fillna("Desconocido")
df_relleno
# Out:
#        cliente             producto   monto        fecha
# 0   Juan Perez  Persiana enrollable  250000   2026-09-01
# 1  Maria Lopez     Cortina blackout  180000   2026-09-02
# 2  Carlos Ruiz          Desconocido  320000   2026-09-03
# 3  Maria Lopez     Cortina blackout  180000   2026-09-02
# 4  Desconocido   Persiana veneciana  150000  Desconocido

# %%
df_decidido = df.dropna(subset=["cliente", "fecha"])
df_decidido
# Out:
#        cliente             producto   monto       fecha
# 0   Juan Perez  Persiana enrollable  250000  2026-09-01
# 1  Maria Lopez     Cortina blackout  180000  2026-09-02
# 2  Carlos Ruiz                  NaN  320000  2026-09-03
# 3  Maria Lopez     Cortina blackout  180000  2026-09-02

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
df_sin_duplicados = df.drop_duplicates()
df_sin_duplicados
# Out:
#        cliente             producto   monto       fecha
# 0   Juan Perez  Persiana enrollable  250000  2026-09-01
# 1  Maria Lopez     Cortina blackout  180000  2026-09-02
# 2  Carlos Ruiz                  NaN  320000  2026-09-03
# 4          NaN   Persiana veneciana  150000         NaN

# %%
print(df.shape)
print(df_sin_duplicados.shape)
# Out:
# (5, 4)
# (4, 4)

# %%
df = pd.DataFrame({
    "cliente": ["Juan Perez", "Maria Lopez", "Carlos Ruiz", "Maria Lopez", None],
    "producto": ["Persiana enrollable", "Cortina blackout", None, "Cortina blackout", "Persiana veneciana"],
    "monto": ["250000", "180000", "320000", "180000", "150000"],
    "fecha": ["2026-09-01", "2026-09-02", "2026-09-03", "2026-08-12", None]
})

# %%
df
# Out:
#        cliente             producto   monto       fecha
# 0   Juan Perez  Persiana enrollable  250000  2026-09-01
# 1  Maria Lopez     Cortina blackout  180000  2026-09-02
# 2  Carlos Ruiz                  NaN  320000  2026-09-03
# 3  Maria Lopez     Cortina blackout  180000  2026-08-12
# 4          NaN   Persiana veneciana  150000         NaN

# %%
df.drop_duplicates()
# Out:
#        cliente             producto   monto       fecha
# 0   Juan Perez  Persiana enrollable  250000  2026-09-01
# 1  Maria Lopez     Cortina blackout  180000  2026-09-02
# 2  Carlos Ruiz                  NaN  320000  2026-09-03
# 3  Maria Lopez     Cortina blackout  180000  2026-08-12
# 4          NaN   Persiana veneciana  150000         NaN

# %%
df.drop_duplicates(subset=["cliente", "producto", "monto"])
# Out:
#        cliente             producto   monto       fecha
# 0   Juan Perez  Persiana enrollable  250000  2026-09-01
# 1  Maria Lopez     Cortina blackout  180000  2026-09-02
# 2  Carlos Ruiz                  NaN  320000  2026-09-03
# 4          NaN   Persiana veneciana  150000         NaN

# %%
df.drop_duplicates(subset=["cliente"])
# Out:
#        cliente             producto   monto       fecha
# 0   Juan Perez  Persiana enrollable  250000  2026-09-01
# 1  Maria Lopez     Cortina blackout  180000  2026-09-02
# 2  Carlos Ruiz                  NaN  320000  2026-09-03
# 4          NaN   Persiana veneciana  150000         NaN

# %%
df.drop_duplicates(subset=["cliente", "producto", "monto", "fecha"])
# Out:
#        cliente             producto   monto       fecha
# 0   Juan Perez  Persiana enrollable  250000  2026-09-01
# 1  Maria Lopez     Cortina blackout  180000  2026-09-02
# 2  Carlos Ruiz                  NaN  320000  2026-09-03
# 3  Maria Lopez     Cortina blackout  180000  2026-08-12
# 4          NaN   Persiana veneciana  150000         NaN

# %%
df.dtypes
# Out:
# cliente     str
# producto    str
# monto       str
# fecha       str
# dtype: object

# %%
df["monto"] = df["monto"].astype(int)
df.dtypes
# Out:
# cliente       str
# producto      str
# monto       int64
# fecha         str
# dtype: object

# %%
df["monto"].sum()
# Out:
# np.int64(1080000)

# %%
df_limpio = (
    df
    .dropna(subset=["cliente", "fecha"])
    .drop_duplicates(subset=["cliente", "producto", "monto", "fecha"])
)
df_limpio["monto"] = df_limpio["monto"].astype(int)
df_limpio
# Out:
#        cliente             producto   monto       fecha
# 0   Juan Perez  Persiana enrollable  250000  2026-09-01
# 1  Maria Lopez     Cortina blackout  180000  2026-09-02
# 2  Carlos Ruiz                  NaN  320000  2026-09-03
# 3  Maria Lopez     Cortina blackout  180000  2026-08-12

# %%
df_limpio.shape
df_limpio.dtypes
# Out:
# cliente       str
# producto      str
# monto       int64
# fecha         str
# dtype: object
